# %% [markdown]
# <a href="https://colab.research.google.com/github/narendramanikala/-sales-dashboard/blob/main/thirenex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================
# Data Cleaning & Reporting Automation Project
# ============================================

# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ============================================
# STEP 1: Load Dataset
# ============================================

df = pd.read_csv("/content/archive (2).zip")

print("Original Dataset:\n")
print(df.head())

# ============================================
# STEP 2: Check Missing Values
# ============================================

print("\nMissing Values:\n")
print(df.isnull().sum())

# Fill Missing Numerical Values with Mean

df['Age'] = df['Age'].fillna(df['Age'].mean())

df['Annual Income (k$)'] = df['Annual Income (k$)'].fillna(
    df['Annual Income (k$)'].mean()
)

df['Spending Score (1-100)'] = df['Spending Score (1-100)'].fillna(
    df['Spending Score (1-100)'].mean()
)

# ============================================
# STEP 3: Remove Duplicates
# ============================================

duplicates = df.duplicated().sum()

print("\nDuplicate Rows:", duplicates)

df = df.drop_duplicates()

# ============================================
# STEP 4: Standardize Text Data
# ============================================

df['Gender'] = df['Gender'].str.strip()
df['Gender'] = df['Gender'].str.capitalize()

# ============================================
# STEP 5: Dataset Summary
# ============================================

print("\nCleaned Dataset Info:\n")
print(df.info())

print("\nStatistical Summary:\n")
print(df.describe())

# ============================================
# STEP 6: Generate Automated Report
# ============================================

report = pd.DataFrame({
    "Column Name": df.columns,
    "Missing Values": df.isnull().sum().values,
    "Data Type": df.dtypes.values
})

print("\nAutomated Report:\n")
print(report)

# Save Report
report.to_csv("automation_report.csv", index=False)

# ============================================
# STEP 7: Visualization
# ============================================

# Age Distribution

plt.figure(figsize=(8,5))

plt.hist(df['Age'], bins=10)

plt.title("Age Distribution")

plt.xlabel("Age")
plt.ylabel("Count")

plt.grid(True)

plt.show()

# ============================================
# STEP 8: Income vs Spending
# ============================================

plt.figure(figsize=(8,5))

plt.scatter(
    df['Annual Income (k$)'],
    df['Spending Score (1-100)']
)

plt.title("Income vs Spending Score")

plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score")

plt.grid(True)

plt.show()

# ============================================
# STEP 9: Save Cleaned Dataset
# ============================================

df.to_csv("Cleaned_Mall_Customers.csv", index=False)

print("\nCleaned dataset saved successfully.")

print("Automation report saved successfully.")
# Out:
# Original Dataset:
#
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
# Missing Values:
#
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64
#
# Duplicate Rows: 0
#
# Cleaned Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
# ...
